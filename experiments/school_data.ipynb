# %%
import pandas as pd
# %matplotlib inline
import pylab as plt
import numpy as np

# %%
school_data = pd.read_csv('data/pubschls.csv')
# school_data = school_data.sort_values('School')
school_data.head()
# Out:
#               CDSCode  NCESDist  NCESSchool StatusType          County  \
# 10035  33671730119297  629550.0     12602.0     Active       Riverside
# 8372   29102982930121  691023.0         NaN     Merged          Nevada
# 469     1612590125856  628050.0     13190.0     Closed         Alameda
# 11722  36679186113385  641040.0      6454.0     Closed  San Bernardino
# 7442   21654170126912  627720.0     13070.0     Closed           Marin
#
#                                 District  \
# 10035               Palm Springs Unified
# 8372   Nevada County Office of Education
# 469                      Oakland Unified
# 11722                  Victor Elementary
# 7442                      Novato Unified
#
#                                         School  \
# 10035                            "Virtual" Pre
# 8372                               '3R' Middle
# 469    100 Black Men of the Bay Area Community
# 11722                           101 Elementary
# ...

# %%
school_data[school_data['County'] == 'Alameda']
# Out:
#            CDSCode  NCESDist  NCESSchool StatusType   County  \
# 469  1612590125856  628050.0     13190.0     Closed  Alameda
# 147  1611506090344  607800.0         NaN     Closed  Alameda
# 395  1612590100693  628050.0         NaN     Closed  Alameda
# 585  1612596002273  628050.0     10730.0     Active  Alameda
# 446  1612590115238  628050.0     12040.0     Active  Alameda
# 625  1612596118608  628050.0      8677.0     Active  Alameda
# 429  1612590111476  628050.0     11561.0     Active  Alameda
# 475  1612590130070  628050.0         NaN     Closed  Alameda
# 52   1611190130120  601770.0     13205.0     Active  Alameda
# 54   1611190130476  601770.0         NaN     Closed  Alameda
# 55   1611190130609  601770.0      8673.0     Active  Alameda
# 9    1100170130419  691051.0      6830.0     Active  Alameda
# 8    1100170130401  691051.0      9264.0     Active  Alameda
# 10   1100170130427  691051.0      9265.0     Closed  Alameda
# ...

# %%
old_data[old_data['county'] == 'Alameda']
# Out:
#                 campus  year                          school  school_num  \
# 21            Berkeley  1994             ALAMEDA HIGH SCHOOL       50005
# 22            Berkeley  1994             ALAMEDA HIGH SCHOOL       50005
# 23            Berkeley  1994             ALAMEDA HIGH SCHOOL       50005
# 24            Berkeley  1994              ALBANY HIGH SCHOOL       50035
# 25            Berkeley  1994              ALBANY HIGH SCHOOL       50035
# 26            Berkeley  1994              ALBANY HIGH SCHOOL       50035
# 43            Berkeley  1994       AMADOR VALLEY HIGH SCHOOL       52495
# 44            Berkeley  1994       AMADOR VALLEY HIGH SCHOOL       52495
# 45            Berkeley  1994            AMERICAN HIGH SCHOOL       50974
# 46            Berkeley  1994            AMERICAN HIGH SCHOOL       50974
# 47            Berkeley  1994            AMERICAN HIGH SCHOOL       50974
# 82            Berkeley  1994              ARROYO HIGH SCHOOL       53125
# ...

# %%
school_data[school_data['NCESSchool'] == 52910]
# Out:
# Empty DataFrame
# Columns: [CDSCode, NCESDist, NCESSchool, StatusType, County, District, School, Street, StreetAbr, City, Zip, State, MailStreet, MailStrAbr, MailCity, MailZip, MailState, Phone, Ext, WebSite, OpenDate, ClosedDate, Charter, CharterNum, FundingType, DOC, DOCType, SOC, SOCType, EdOpsCode, EdOpsName, EILCode, EILName, GSoffered, GSserved, Virtual, Magnet, Latitude, Longitude, AdmFName1, AdmLName1, AdmEmail1, AdmFName2, AdmLName2, AdmEmail2, AdmFName3, AdmLName3, AdmEmail3, LastUpDate]
# Index: []
#
# [0 rows x 49 columns]

# %%
school_data[school_data['CDSCode'].astype(str).str[-7:].astype(float) == 52910]
# Out:
# Empty DataFrame
# Columns: [CDSCode, NCESDist, NCESSchool, StatusType, County, District, School, Street, StreetAbr, City, Zip, State, MailStreet, MailStrAbr, MailCity, MailZip, MailState, Phone, Ext, WebSite, OpenDate, ClosedDate, Charter, CharterNum, FundingType, DOC, DOCType, SOC, SOCType, EdOpsCode, EdOpsName, EILCode, EILName, GSoffered, GSserved, Virtual, Magnet, Latitude, Longitude, AdmFName1, AdmLName1, AdmEmail1, AdmFName2, AdmLName2, AdmEmail2, AdmFName3, AdmLName3, AdmEmail3, LastUpDate]
# Index: []
#
# [0 rows x 49 columns]

# %%
school_data.columns
# Out:
# Index(['CDSCode', 'NCESDist', 'NCESSchool', 'StatusType', 'County', 'District',
#        'School', 'Street', 'StreetAbr', 'City', 'Zip', 'State', 'MailStreet',
#        'MailStrAbr', 'MailCity', 'MailZip', 'MailState', 'Phone', 'Ext',
#        'WebSite', 'OpenDate', 'ClosedDate', 'Charter', 'CharterNum',
#        'FundingType', 'DOC', 'DOCType', 'SOC', 'SOCType', 'EdOpsCode',
#        'EdOpsName', 'EILCode', 'EILName', 'GSoffered', 'GSserved', 'Virtual',
#        'Magnet', 'Latitude', 'Longitude', 'AdmFName1', 'AdmLName1',
#        'AdmEmail1', 'AdmFName2', 'AdmLName2', 'AdmEmail2', 'AdmFName3',
#        'AdmLName3', 'AdmEmail3', 'LastUpDate'],
#       dtype='object')

# %%
old_data = pd.read_csv('data/processed.csv')
old_data.head()
# Out:
#      campus  year                       school  school_num           city  \
# 0  Berkeley  1994  ABRAHAM LINCOLN HIGH SCHOOL       51520    Los Angeles
# 1  Berkeley  1994  ABRAHAM LINCOLN HIGH SCHOOL       51520    Los Angeles
# 2  Berkeley  1994  ABRAHAM LINCOLN HIGH SCHOOL       51520    Los Angeles
# 3  Berkeley  1994  ABRAHAM LINCOLN HIGH SCHOOL       52910  San Francisco
# 4  Berkeley  1994  ABRAHAM LINCOLN HIGH SCHOOL       52910  San Francisco
#
#           county       state country         region         ethnicity  \
# 0    Los Angeles  California     USA    Los Angeles               All
# 1    Los Angeles  California     USA    Los Angeles             Asian
# 2    Los Angeles  California     USA    Los Angeles  Hispanic/ Latino
# 3  San Francisco  California     USA  San Francisco               All
# 4  San Francisco  California     USA  San Francisco             Asian
#
#    app_num  adm_num  enr_num   app_gpa  adm_gpa   enr_gpa
# ...
